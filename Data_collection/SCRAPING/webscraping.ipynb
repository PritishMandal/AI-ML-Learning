# %%
# web scriping
import requests

URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

print(res.status_code)
# Out:
# 200

# %%
if res.status_code == 200:
 print(res.headers)
with open("scraped_data/data1.html","w") as f:
    f.write(res.text)
# Out:
# {'Date': 'Tue, 04 Aug 2026 14:11:53 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=fATUGvtyffabH1SBhe4TmJuAt5O18UczprmwhCbN8BY%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1785852713"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=fATUGvtyffabH1SBhe4TmJuAt5O18UczprmwhCbN8BY%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1785852713"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': 'a25e2760ccdde1c0-MRS', 'alt-svc': 'h3=":443"; ma=86400'}
# ------------------------------------------------------------------------
# UnicodeEncodeError                     Traceback (most recent call last)
# Cell In[10], line 4
#       2  print(res.headers)
#       3 with open("scraped_data/data1.html","w") as f:
# ----> 4     f.write(res.text)
#
# File ~\anaconda3\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u015f' in position 115200: character maps to <undefined>
