# %%
# web scriping
import requests

URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

print(res.status_code)
# Out:
# 200

# %%
if res.status_code == 200:
 print(res.headers)
with open("scraped_data/data1.html", "w", encoding="utf-8") as f:
    f.write(res.text)
# Out:
# {'Date': 'Tue, 04 Aug 2026 14:34:24 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=XjU8LOcGn%2FhpH8r4MzMYwIgE0BEQF%2B3SnlYXhElHSaM%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1785854064"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=XjU8LOcGn%2FhpH8r4MzMYwIgE0BEQF%2B3SnlYXhElHSaM%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1785854064"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': 'a25e485c5b2e408b-SIN', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
# BeautifulSoup

from bs4 import BeautifulSoup

with open("scraped_data/data1.html", "r", encoding="utf-8") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "html.parser")

# %%
all_h3 = soup.find_all("h3")

all_countries = []

for h3 in all_h3:
    name = h3.get_text(strip=True)
    population = h3.find_next("div").select_one("span.country-population").get_text(strip=True)

    all_countries.append([name, population])

# %%
import pandas as pd

df = pd.DataFrame(all_countries,columns=["Name","Population"])

# %%
df.to_csv("cleaned_data/data.csv", index=False)
