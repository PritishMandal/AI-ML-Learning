# %%
import pandas as pd

# %%
info = {
    "Name" : ["shrutika", "Pritish", ],
    "CGPA" : [9.56,9.51]
}
df = pd.DataFrame(info)

print(df)
# Out:
#        Name  CGPA
# 0  shrutika  9.56
# 1   Pritish  9.51

# %%
df
# Out:
#        Name  CGPA
# 0  shrutika  9.56
# 1   Pritish  9.51

# %%
s =pd.Series([1,2,3,4,5])
print(s)
print(type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
