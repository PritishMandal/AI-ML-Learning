# %%
import pandas as pd

# %%
info = {
    "Name" : ["shrutika", "Pritish", ],
    "CGPA" : [8.79,8.45]
}
df = pd.DataFrame(info)

print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 info = {
#       2     "Name" : ["shrutika", "Pritish", ],
#       3     "CGPA" : [8.79,8.45]
#       4 }
# ----> 5 df = pd.DataFrame(info)
#       7 print(df)
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#        Name  CGPA
# 0  shrutika  9.56
# 1   Pritish  9.51

# %%
s =pd.Series([1,2,3,4,5])
print(s)
print(type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
